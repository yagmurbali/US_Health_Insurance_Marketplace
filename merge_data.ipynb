# %%
from zipfile import ZipFile
from urllib.request import urlopen   
import pandas as pd
import os
import zipfile

# %%
URL1 = \
    'https://download.cms.gov/marketplace-puf/2018/benefits-and-cost-sharing-puf.zip'

# open and save the zip file onto computer
url1 = urlopen(URL1)
output = open('benefits-and-cost-sharing-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url1.read())
output.close()

# read the zip file as a pandas dataframe
benefit_cost = pd.read_csv('benefits-and-cost-sharing-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
benefit_cost.info()
# Out:
# /Users/yagmurbali/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829652 entries, 0 to 829651
# Data columns (total 24 columns):
# BusinessYear           829652 non-null int64
# StateCode              829652 non-null object
# IssuerId               829652 non-null int64
# SourceName             829652 non-null object
# ImportDate             829652 non-null object
# StandardComponentId    829652 non-null object
# PlanId                 829652 non-null object
# BenefitName            829652 non-null object
# CopayInnTier1          646629 non-null object
# CopayInnTier2          121865 non-null object
# CopayOutofNet          646629 non-null object
# CoinsInnTier1          646629 non-null object
# ...

# %%
URL2 = \
    'https://download.cms.gov/marketplace-puf/2018/rate-puf.zip'

# open and save the zip file onto computer
url2 = urlopen(URL2)
output = open('rate-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url2.read())
output.close()

# read the zip file as a pandas dataframe
rate = pd.read_csv('rate-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
rate.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 1          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 2          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 3          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 4          2018        AK     21989       HIOS  2017-09-26 02:21:16
#
#    FederalTIN RateEffectiveDate RateExpirationDate          PlanId  \
# 0  93-0438772        2018-01-01         2018-12-31  21989AK0030001
# 1  93-0438772        2018-01-01         2018-03-31  21989AK0090001
# 2  93-0438772        2018-04-01         2018-06-30  21989AK0090001
# 3  93-0438772        2018-07-01         2018-09-30  21989AK0090001
# 4  93-0438772        2018-10-01         2018-12-31  21989AK0090001
#
#     RatingAreaId  ...   Age IndividualRate  IndividualTobaccoRate  Couple  \
# 0  Rating Area 1  ...  0-14           53.0                    NaN     NaN
# ...

# %%
URL3 = \
    'https://download.cms.gov/marketplace-puf/2018/business-rules-puf.zip'

# open and save the zip file onto computer
url3 = urlopen(URL3)
output = open('business-rules-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url3.read())
output.close()

# read the zip file as a pandas dataframe
business_rules = pd.read_csv('business-rules-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
business_rules.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 1          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 2          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 3          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 4          2018        AK     21989       HIOS  2017-09-26 02:21:16
#
#           TIN   ProductId StandardComponentId  \
# 0  93-0438772  21989AK003      21989AK0030001
# 1  93-0438772  21989AK005      21989AK0050001
# 2  93-0438772  21989AK005      21989AK0050002
# 3  93-0438772  21989AK007      21989AK0070001
# 4  93-0438772  21989AK008      21989AK0080001
#
#                EnrolleeContractRateDeterminationRule  \
# 0  A different rate (specifically for parties of ...
# 1  A different rate (specifically for parties of ...
# 2  A different rate (specifically for parties of ...
# 3  A different rate (specifically for parties of ...
# ...

# %%
URL4 = \
    'https://download.cms.gov/marketplace-puf/2018/service-area-puf.zip'

# open and save the zip file onto computer
url4 = urlopen(URL4)
output = open('service-area-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url4.read())
output.close()

# read the zip file as a pandas dataframe
service_area = pd.read_csv('service-area-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
service_area.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2018        WI     86584       HIOS  2017-08-05 02:21:19
# 1          2018        WI     87416       HIOS  2018-01-18 02:20:16
# 2          2018        WI     87416       HIOS  2018-01-18 02:20:16
# 3          2018        WI     87416       HIOS  2018-01-18 02:20:16
# 4          2018        WI     87416       HIOS  2018-01-18 02:20:16
#
#   ServiceAreaId    ServiceAreaName CoverEntireState   County PartialCounty  \
# 0        WIS001       AspirusArise               No  55115.0           Yes
# 1        WIS001  CGHC Service Area               No  55009.0            No
# 2        WIS001  CGHC Service Area               No  55015.0            No
# 3        WIS001  CGHC Service Area               No  55029.0            No
# 4        WIS001  CGHC Service Area               No  55039.0            No
#
#                                             ZipCodes  \
# ...

# %%
URL5 = \
    'https://download.cms.gov/marketplace-puf/2018/network-puf.zip'

# open and save the zip file onto computer
url5 = urlopen(URL5)
output = open('network-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url5.read())
output.close()

# read the zip file as a pandas dataframe
network = pd.read_csv('network-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
network.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 1          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 2          2018        AK     38344       HIOS  2017-11-01 02:20:20
# 3          2018        AK     73836       HIOS  2017-09-02 02:21:27
# 4          2018        AK     73836       HIOS  2017-09-02 02:21:27
#
#                       NetworkName NetworkId  \
# 0            Delta Dental Premier    AKN001
# 1                Delta Dental PPO    AKN002
# 2  HeritagePlus and Dental Choice    AKN001
# 3             Endeavor Providence    AKN002
# 4                 Endeavor Select    AKN001
#
#                                           NetworkURL MarketCoverage  \
# 0  https://www.modahealth.com/shop/provider-searc...            NaN
# 1  https://www.modahealth.com/shop/provider-searc...            NaN
# 2  https://premera.vitalschoice.com/?ci=premeraak...            NaN
# ...

# %%
URL6 = \
    'https://download.cms.gov/marketplace-puf/2018/plan-attributes-puf.zip'

# open and save the zip file onto computer
url6 = urlopen(URL6)
output = open('plan-attributes-puf.zip', 'wb')    # note the flag:  "wb"        
output.write(url6.read())
output.close()

# read the zip file as a pandas dataframe
plan_attributes = pd.read_csv('plan-attributes-puf.zip', encoding='cp1252')   # pandas version 0.18.1 takes zip files       

# if keeping on disk the zip file is not wanted, then:
#os.remove(zipName)   # remove the copy of the zipfile on diskbenefit_cost.head()
plan_attributes.head()
# Out:
# /Users/yagmurbali/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (81,82,83,87,88,89,90,91,92,112,123,124,125,126,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 1          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 2          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 3          2018        AK     21989       HIOS  2017-09-26 02:21:16
# 4          2018        AK     21989       HIOS  2017-09-26 02:21:16
#
#        MarketCoverage DentalOnlyPlan         TIN StandardComponentId  \
# 0  SHOP (Small Group)            Yes  93-0438772      21989AK0130001
# 1          Individual            Yes  93-0438772      21989AK0030001
# ...

# %%
rate.groupby(['Tobacco', 'IndividualTobaccoRate', 'IndividualRate']).count().sample()
# Out:
#                                                                     BusinessYear  \
# Tobacco                       IndividualTobaccoRate IndividualRate
# Tobacco User/Non-Tobacco User 508.58                479.79                     1
#
#                                                                     StateCode  \
# Tobacco                       IndividualTobaccoRate IndividualRate
# Tobacco User/Non-Tobacco User 508.58                479.79                  1
#
#                                                                     IssuerId  \
# Tobacco                       IndividualTobaccoRate IndividualRate
# Tobacco User/Non-Tobacco User 508.58                479.79                 1
#
#                                                                     SourceName  \
# Tobacco                       IndividualTobaccoRate IndividualRate
# Tobacco User/Non-Tobacco User 508.58                479.79                   1
#
# ...

# %%
#There are 39 state
rate.StateCode.unique()
# Out:
# array(['AK', 'AL', 'AZ', 'FL', 'GA', 'IN', 'LA', 'MO', 'MS', 'NC', 'ND',
#        'NJ', 'OK', 'SC', 'TN', 'TX', 'WI', 'WY', 'AR', 'DE', 'HI', 'IA',
#        'IL', 'KS', 'KY', 'ME', 'MI', 'MT', 'NE', 'NH', 'NM', 'NV', 'OH',
#        'OR', 'PA', 'SD', 'UT', 'VA', 'WV'], dtype=object)

# %%
# If we take a quick look at the IndividualRate column, we will see there are few rates over 9000. It might be written wrong
rate[rate.IndividualRate>9000].IndividualRate.count()
# Out:
# 5954

# %%
rate.Tobacco.sample(50)
rate.groupby(['Tobacco']).count()
# Out:
#                                BusinessYear  StateCode  IssuerId  SourceName  \
# Tobacco
# No Preference                       1768782    1768782   1768782     1768782
# Tobacco User/Non-Tobacco User        517599     517599    517599      517599
#
#                                ImportDate  FederalTIN  RateEffectiveDate  \
# Tobacco
# No Preference                     1768782     1768782            1768782
# Tobacco User/Non-Tobacco User      517599      517599             517599
#
#                                RateExpirationDate   PlanId  RatingAreaId  \
# Tobacco
# No Preference                             1768782  1768782       1768782
# Tobacco User/Non-Tobacco User              517599   517599        517599
#
#                                    Age  IndividualRate  IndividualTobaccoRate  \
# Tobacco
# No Preference                  1768782         1768782                      0
# Tobacco User/Non-Tobacco User   517599          517599                 517599
#
# ...

# %%
benefit_cost.groupby(['QuantLimitOnSvc']).count().tail(100)
# Out:
#                  BusinessYear  StateCode  IssuerId  SourceName  ImportDate  \
# QuantLimitOnSvc
# No                     128317     128317    128317      128317      128317
# Yes                    115021     115021    115021      115021      115021
#
#                  StandardComponentId  PlanId  BenefitName  CopayInnTier1  \
# QuantLimitOnSvc
# No                            128317  128317       128317         124448
# Yes                           115021  115021       115021         114739
#
#                  CopayInnTier2  ...  CoinsOutofNet   IsEHB  IsCovered  \
# QuantLimitOnSvc                 ...
# No                        4305  ...         124448  111387     128317
# Yes                      21377  ...         114739  104573     115021
#
#                  LimitQty  LimitUnit  Exclusions  Explanation  EHBVarReason  \
# QuantLimitOnSvc
# No                      0          0       12940        44762         30181
# ...

# %%
planAttributes= plan_attributes[['IssuerId','MetalLevel', 'DentalOnlyPlan', 'MarketCoverage', 'StateCode']]
planAttributes.head()
# Out:
#    IssuerId MetalLevel DentalOnlyPlan      MarketCoverage StateCode
# 0     21989       High            Yes  SHOP (Small Group)        AK
# 1     21989        Low            Yes          Individual        AK
# 2     21989        Low            Yes          Individual        AK
# 3     21989       High            Yes  SHOP (Small Group)        AK
# 4     21989       High            Yes  SHOP (Small Group)        AK

# %%
rate_= rate[['Age', 'Tobacco', 'IndividualRate', 'IndividualTobaccoRate']]
rate_.head()
# Out:
#     Age        Tobacco  IndividualRate  IndividualTobaccoRate
# 0  0-14  No Preference            53.0                    NaN
# 1  0-14  No Preference            63.0                    NaN
# 2  0-14  No Preference            64.0                    NaN
# 3  0-14  No Preference            65.0                    NaN
# 4  0-14  No Preference            66.0                    NaN

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.truncate.html
rate_ = rate_.truncate(after=14999)

# %%
benefitCost= benefit_cost[['IssuerId','BenefitName', 'IsCovered', 'IsEHB', 'QuantLimitOnSvc', 'IsExclFromInnMOOP', 'IsExclFromOonMOOP']]
benefitCost.head()
# Out:
#    IssuerId                      BenefitName IsCovered IsEHB QuantLimitOnSvc  \
# 0     21989  Routine Dental Services (Adult)   Covered   NaN             Yes
# 1     21989     Dental Check-Up for Children   Covered   Yes             Yes
# 2     21989        Basic Dental Care - Child   Covered   Yes             NaN
# 3     21989              Orthodontia - Child   Covered   Yes             NaN
# 4     21989        Major Dental Care - Child   Covered   Yes             NaN
#
#   IsExclFromInnMOOP IsExclFromOonMOOP
# 0                No                No
# 1                No                No
# 2                No                No
# 3                No                No
# 4                No                No

# %%
benefitCost = benefitCost.truncate(after=14999)

# %%
merged = pd.concat([rate_, benefitCost], axis=1)

# %%
healthInsurance = pd.merge(merged, planAttributes, on='IssuerId')

# %%
healthInsurance.head()
# Out:
#     Age        Tobacco  IndividualRate  IndividualTobaccoRate  IssuerId  \
# 0  0-14  No Preference            53.0                    NaN     21989
# 1  0-14  No Preference            53.0                    NaN     21989
# 2  0-14  No Preference            53.0                    NaN     21989
# 3  0-14  No Preference            53.0                    NaN     21989
# 4  0-14  No Preference            53.0                    NaN     21989
#
#                        BenefitName IsCovered IsEHB QuantLimitOnSvc  \
# 0  Routine Dental Services (Adult)   Covered   NaN             Yes
# 1  Routine Dental Services (Adult)   Covered   NaN             Yes
# 2  Routine Dental Services (Adult)   Covered   NaN             Yes
# 3  Routine Dental Services (Adult)   Covered   NaN             Yes
# 4  Routine Dental Services (Adult)   Covered   NaN             Yes
#
#   IsExclFromInnMOOP IsExclFromOonMOOP MetalLevel DentalOnlyPlan  \
# ...

# %%
healthInsurance.to_csv('healthInsurance.csv')
